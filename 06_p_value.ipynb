# %% [markdown]
# <a href="https://colab.research.google.com/github/glebmikha/ab-testing-course/blob/main/06_p_value.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Мой Telegram-канал: https://t.me/mikhaylovgleb

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # P-value for 7/10

# %%
np.random.binomial(10,0.5)
# Out:
# 4

# %%
n = 10000
result = []
for i in range(n):
  np.random.seed(i)
  result.append(np.random.binomial(10,0.5))

# %%
df = pd.DataFrame(result)

# %%
df
# Out:
#       0
# 0     5
# 1     5
# 2     5
# 3     5
# 4     8
# ...  ..
# 9995  5
# 9996  6
# 9997  2
# 9998  4
# 9999  6
#
# [10000 rows x 1 columns]

# %%
df['dev'] = abs(df[0] - 5)

# %%
df
# Out:
#       0  dev
# 0     5    0
# 1     5    0
# 2     5    0
# 3     5    0
# 4     8    3
# ...  ..  ...
# 9995  5    0
# 9996  6    1
# 9997  2    3
# 9998  4    1
# 9999  6    1
#
# [10000 rows x 2 columns]

# %%
(df['dev'] >= 2).mean()
# Out:
# 0.3515

# %% [markdown]
# # P-value scale

# %%
devs = [0,1,2,3,4,5]

# %%
result = []
for dev in devs:
  result.append((dev,(df['dev'] >= dev).mean()))

# %%
pvals = pd.DataFrame(result,columns=['heads','p-values'])

# %%
pvals
# Out:
#    heads  p-values
# 0      0    1.0000
# 1      1    0.7573
# 2      2    0.3515
# 3      3    0.1124
# 4      4    0.0229
# 5      5    0.0009

# %% [markdown]
# # P-value for satisfaction case

# %% [markdown]
# ## P-value 84 / 115

# %%
sample_size = 115

# %%
n = 10000
result = []
for i in range(n):
  np.random.seed(i)
  result.append(np.random.binomial(sample_size,0.8))

# %%
df = pd.DataFrame(result)

# %%
sample_size * 0.8
# Out:
# 92.0

# %%
df['dev'] = df[0] - sample_size * 0.8

# %%
df
# Out:
#        0  dev
# 0     92  0.0
# 1     93  1.0
# 2     93  1.0
# 3     92  0.0
# 4     84 -8.0
# ...   ..  ...
# 9995  93  1.0
# 9996  90 -2.0
# 9997  99  7.0
# 9998  96  4.0
# 9999  88 -4.0
#
# [10000 rows x 2 columns]

# %%
(df['dev'] <= -8).mean()
# Out:
# 0.0437

# %% [markdown]
# ## Scale

# %%
devs = list(range(0,int(sample_size * 0.8) + 1))

# %%
result = []
for dev in devs:
  result.append((dev,(df['dev'] <= -dev).mean()))

# %%
pvals = pd.DataFrame(result,columns=['people','p-values'])

# %%
pvals
# Out:
#     people  p-values
# 0        0    0.5348
# 1        1    0.4498
# 2        2    0.3632
# 3        3    0.2777
# 4        4    0.2067
# ..     ...       ...
# 88      88    0.0000
# 89      89    0.0000
# 90      90    0.0000
# 91      91    0.0000
# 92      92    0.0000
#
# [93 rows x 2 columns]

# %%
pvals.set_index('people').plot()
# Out:
# <Axes: xlabel='people'>

# %%
pvals.head(18)
# Out:
#     people  p-values
# 0        0    0.5348
# 1        1    0.4498
# 2        2    0.3632
# 3        3    0.2777
# 4        4    0.2067
# 5        5    0.1464
# 6        6    0.1013
# 7        7    0.0685
# 8        8    0.0437
# 9        9    0.0277
# 10      10    0.0169
# 11      11    0.0099
# 12      12    0.0053
# 13      13    0.0030
# 14      14    0.0014
# 15      15    0.0004
# 16      16    0.0002
# 17      17    0.0000

# %% [markdown]
# # P-value with statistical test

# %%
from statsmodels.stats.proportion import proportions_ztest

# %%
proportions_ztest(84,115,0.8,alternative='smaller')
# Out:
# (-1.6811962678215244, 0.046362399106540116)

# %%
pvals['pval_ztest'] = pvals['people'].apply(lambda x: proportions_ztest(92-x,115,0.8,alternative='smaller')[1])

# %%
pvals
# Out:
#     people  p-values  pval_ztest
# 0        0    0.5348    0.500000
# 1        1    0.4498    0.409252
# 2        2    0.3632    0.325579
# 3        3    0.2777    0.251815
# 4        4    0.2067    0.189428
# ..     ...       ...         ...
# 88      88    0.0000    0.000000
# 89      89    0.0000    0.000000
# 90      90    0.0000    0.000000
# 91      91    0.0000    0.000000
# 92      92    0.0000    0.000000
#
# [93 rows x 3 columns]

# %%
pvals.set_index('people').plot()
# Out:
# <Axes: xlabel='people'>

# %% [markdown]
# Мой Telegram-канал: https://t.me/mikhaylovgleb
